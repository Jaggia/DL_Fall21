# %% [markdown]
# Load Data: https://www.kaggle.com/rmisra/news-category-dataset/code?datasetId=32526&searchQuery=df+%3D+pd.read_json%28file_path%2C+lines+%3D+True%29
#
# Main Code: https://www.kaggle.com/hengzheng/news-category-classifier-val-acc-0-65

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import pandas as pd
def load_data(file_path):
    df = pd.read_json(file_path, lines = True)
    df['category'] = pd.Categorical(df['category'])
    df = df[df["short_description"] != ""]
    df['headlineDesc'] = df['headline']+ ' ' + df['short_description']
    return df[["headlineDesc", "category"]]

df = load_data('News_Category_Dataset_v2.json')
df.head()
# Out:
#                                         headlineDesc       category
# 0  There Were 2 Mass Shootings In Texas Last Week...          CRIME
# 1  Will Smith Joins Diplo And Nicky Jam For The 2...  ENTERTAINMENT
# 2  Hugh Grant Marries For The First Time At Age 5...  ENTERTAINMENT
# 3  Jim Carrey Blasts 'Castrato' Adam Schiff And D...  ENTERTAINMENT
# 4  Julianna Margulies Uses Donald Trump Poop Bags...  ENTERTAINMENT

# %%
#different than baseline (keras instead of spacy)
from keras.preprocessing.text import Tokenizer
# tokenizing
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df.headlineDesc)
X = tokenizer.texts_to_sequences(df.headlineDesc)
df['words'] = X
vocab_size = len(tokenizer.word_index) + 1
# delete some empty and short data
df['word_length'] = df.words.apply(lambda i: len(i))
df = df[df.word_length >= 5]
df.head()
# Out:
#                                         headlineDesc  ... word_length
# 0  There Were 2 Mass Shootings In Texas Last Week...  ...          27
# 1  Will Smith Joins Diplo And Nicky Jam For The 2...  ...          20
# 2  Hugh Grant Marries For The First Time At Age 5...  ...          25
# 3  Jim Carrey Blasts 'Castrato' Adam Schiff And D...  ...          26
# 4  Julianna Margulies Uses Donald Trump Poop Bags...  ...          26
#
# [5 rows x 4 columns]

# %%
from keras.preprocessing import sequence
import numpy as np
maxlen = 50
X = list(sequence.pad_sequences(df.words, maxlen=maxlen))
categories = df.groupby('category').size().index.tolist()
category_int = {}
int_category = {}
for i, k in enumerate(categories):
    category_int.update({k:i})
    int_category.update({i:k})

df['c2id'] = df['category'].apply(lambda x: category_int[x])

word_index = tokenizer.word_index

EMBEDDING_DIM = 100

embeddings_index = {}
f = open('glove.6B.100d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s unique tokens.' % len(word_index))
print('Total %s word vectors.' % len(embeddings_index))
# Out:
# Found 114348 unique tokens.
# Total 400000 word vectors.

# %%
from keras import layers
from keras.initializers import Constant
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

embedding_layer = layers.Embedding(len(word_index)+1,
                            EMBEDDING_DIM,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=maxlen,
                            trainable=False)

X = np.array(X)
Y = np_utils.to_categorical(list(df.c2id))

# split to training set and validation set
seed = 1234
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.3, random_state=seed)

# %%
from keras.models import Sequential, Model
from keras.backend import clear_session
clear_session()

from tensorflow.keras import models
## code attention layer
def attention_layer(inputs, neurons):
    x = layers.Permute((2,1))(inputs)
    x = layers.Dense(neurons, activation="softmax")(x)
    x = layers.Permute((2,1), name="attention")(x)
    x = layers.multiply([inputs, x])
    return x

## input
inp = layers.Input(shape=(maxlen,), dtype='int32')
embedding_layer = layers.Embedding(len(word_index)+1,
                            EMBEDDING_DIM,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=maxlen,
                            trainable=False)

## embedding
x = embedding_layer(inp)
## apply attention
x = attention_layer(x, neurons=50)
## 2 layers of bidirectional lstm
x = layers.Bidirectional(layers.LSTM(units=50, dropout=0.5, return_sequences=True))(x)
x = layers.Bidirectional(layers.LSTM(units=50, dropout=0.2))(x)
## final dense layers
x = layers.Dense(64, activation='relu')(x)
y_out = layers.Dense(41, activation='softmax')(x)
## compile
model = models.Model(inp, y_out)
model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 50)]         0           []
#
#  embedding (Embedding)          (None, 50, 100)      11434900    ['input_1[0][0]']
#
#  permute (Permute)              (None, 100, 50)      0           ['embedding[0][0]']
#
#  dense (Dense)                  (None, 100, 50)      2550        ['permute[0][0]']
#
#  attention (Permute)            (None, 50, 100)      0           ['dense[0][0]']
#
#  multiply (Multiply)            (None, 50, 100)      0           ['embedding[0][0]',
#                                                                   'attention[0][0]']
#
#  bidirectional (Bidirectional)  (None, 50, 100)      60400       ['multiply[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 100)         60400       ['bidirectional[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 64)           6464        ['bidirectional_1[0][0]']
#
#  dense_2 (Dense)                (None, 41)           2665        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 11,567,379
# Trainable params: 132,479
# Non-trainable params: 11,434,900
# __________________________________________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=30, batch_size=64, validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 1982/1982 [==============================] - 40s 18ms/step - loss: 2.5894 - accuracy: 0.3258 - val_loss: 2.3154 - val_accuracy: 0.3665
# Epoch 2/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 2.1849 - accuracy: 0.4049 - val_loss: 2.0353 - val_accuracy: 0.4429
# Epoch 3/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 2.0536 - accuracy: 0.4353 - val_loss: 1.9266 - val_accuracy: 0.4666
# Epoch 4/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.9616 - accuracy: 0.4592 - val_loss: 1.8135 - val_accuracy: 0.4960
# Epoch 5/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.8846 - accuracy: 0.4775 - val_loss: 1.7777 - val_accuracy: 0.5042
# Epoch 6/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.8253 - accuracy: 0.4913 - val_loss: 1.7170 - val_accuracy: 0.5213
# Epoch 7/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.7757 - accuracy: 0.5042 - val_loss: 1.6826 - val_accuracy: 0.5286
# Epoch 8/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.7320 - accuracy: 0.5153 - val_loss: 1.6520 - val_accuracy: 0.5342
# Epoch 9/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.6981 - accuracy: 0.5234 - val_loss: 1.6049 - val_accuracy: 0.5483
# Epoch 10/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.6659 - accuracy: 0.5301 - val_loss: 1.5962 - val_accuracy: 0.5500
# Epoch 11/30
# 1981/1982 [============================>.] - ETA: 0s - loss: 1.6383 - accuracy: 0.5374Epoch 12/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.6132 - accuracy: 0.5432 - val_loss: 1.5424 - val_accuracy: 0.5651
# Epoch 13/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.5891 - accuracy: 0.5496 - val_loss: 1.5318 - val_accuracy: 0.5649
# Epoch 14/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.5705 - accuracy: 0.5541 - val_loss: 1.5076 - val_accuracy: 0.5713
# Epoch 15/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.5529 - accuracy: 0.5577 - val_loss: 1.5033 - val_accuracy: 0.5728
# Epoch 16/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.5345 - accuracy: 0.5631 - val_loss: 1.4805 - val_accuracy: 0.5769
# Epoch 17/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.5201 - accuracy: 0.5661 - val_loss: 1.4858 - val_accuracy: 0.5798
# Epoch 18/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.5066 - accuracy: 0.5689 - val_loss: 1.4625 - val_accuracy: 0.5837
# Epoch 19/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.4932 - accuracy: 0.5726 - val_loss: 1.4508 - val_accuracy: 0.5868
# Epoch 20/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.4836 - accuracy: 0.5748 - val_loss: 1.4598 - val_accuracy: 0.5836
# Epoch 21/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.4706 - accuracy: 0.5779 - val_loss: 1.4322 - val_accuracy: 0.5910
# Epoch 22/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.4603 - accuracy: 0.5811 - val_loss: 1.4237 - val_accuracy: 0.5927
# Epoch 23/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.4496 - accuracy: 0.5816 - val_loss: 1.4231 - val_accuracy: 0.5932
# Epoch 24/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.4427 - accuracy: 0.5847 - val_loss: 1.4208 - val_accuracy: 0.5923
# Epoch 25/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.4308 - accuracy: 0.5881 - val_loss: 1.4180 - val_accuracy: 0.5960
# Epoch 26/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.4244 - accuracy: 0.5892 - val_loss: 1.4055 - val_accuracy: 0.5993
# Epoch 27/30
# 1982/1982 [==============================] - 34s 17ms/step - loss: 1.4126 - accuracy: 0.5921 - val_loss: 1.4052 - val_accuracy: 0.6000
# Epoch 28/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.4086 - accuracy: 0.5937 - val_loss: 1.4106 - val_accuracy: 0.5986
# Epoch 29/30
# 1982/1982 [==============================] - 33s 17ms/step - loss: 1.3995 - accuracy: 0.5941 - val_loss: 1.3953 - val_accuracy: 0.6005
# Epoch 30/30
# 1982/1982 [==============================] - 39s 20ms/step - loss: 1.3928 - accuracy: 0.5969 - val_loss: 1.3922 - val_accuracy: 0.6015

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (6,6)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.title('Training and validation accuracy')
plt.plot(epochs, acc, 'red', label='Training acc')
plt.plot(epochs, val_acc, 'blue', label='Validation acc')
plt.legend()

plt.figure()
plt.title('Training and validation loss')
plt.plot(epochs, loss, 'red', label='Training loss')
plt.plot(epochs, val_loss, 'blue', label='Validation loss')
plt.legend()

plt.show()

# %%
# Final evaluation of the model
scores = model.evaluate(x_val, y_val, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 60.15%
