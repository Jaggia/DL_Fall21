# %% [markdown]
# Load Data: https://www.kaggle.com/rmisra/news-category-dataset/code?datasetId=32526&searchQuery=df+%3D+pd.read_json%28file_path%2C+lines+%3D+True%29
#
# Main Code: https://www.kaggle.com/hengzheng/news-category-classifier-val-acc-0-65

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import pandas as pd
def load_data(file_path):
    df = pd.read_json(file_path, lines = True)
    df['category'] = pd.Categorical(df['category'])
    df = df[df["short_description"] != ""]
    df['headlineDesc'] = df['headline']+ ' ' + df['short_description']
    return df[["headlineDesc", "category"]]

df = load_data('News_Category_Dataset_v2.json')
df.head()
# Out:
#                                         headlineDesc       category
# 0  There Were 2 Mass Shootings In Texas Last Week...          CRIME
# 1  Will Smith Joins Diplo And Nicky Jam For The 2...  ENTERTAINMENT
# 2  Hugh Grant Marries For The First Time At Age 5...  ENTERTAINMENT
# 3  Jim Carrey Blasts 'Castrato' Adam Schiff And D...  ENTERTAINMENT
# 4  Julianna Margulies Uses Donald Trump Poop Bags...  ENTERTAINMENT

# %%
#different than baseline (keras instead of spacy)
from keras.preprocessing.text import Tokenizer
# tokenizing
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df.headlineDesc)
X = tokenizer.texts_to_sequences(df.headlineDesc)
df['words'] = X
vocab_size = len(tokenizer.word_index) + 1
# delete some empty and short data
df['word_length'] = df.words.apply(lambda i: len(i))
df = df[df.word_length >= 5]
df.head()
# Out:
#                                         headlineDesc  ... word_length
# 0  There Were 2 Mass Shootings In Texas Last Week...  ...          27
# 1  Will Smith Joins Diplo And Nicky Jam For The 2...  ...          20
# 2  Hugh Grant Marries For The First Time At Age 5...  ...          25
# 3  Jim Carrey Blasts 'Castrato' Adam Schiff And D...  ...          26
# 4  Julianna Margulies Uses Donald Trump Poop Bags...  ...          26
#
# [5 rows x 4 columns]

# %%
from keras.preprocessing import sequence
import numpy as np
maxlen = 50
X = list(sequence.pad_sequences(df.words, maxlen=maxlen))
categories = df.groupby('category').size().index.tolist()
category_int = {}
int_category = {}
for i, k in enumerate(categories):
    category_int.update({k:i})
    int_category.update({i:k})

df['c2id'] = df['category'].apply(lambda x: category_int[x])

word_index = tokenizer.word_index

EMBEDDING_DIM = 100

embeddings_index = {}
f = open('glove.6B.100d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s unique tokens.' % len(word_index))
print('Total %s word vectors.' % len(embeddings_index))
# Out:
# Found 114348 unique tokens.
# Total 400000 word vectors.

# %%
from keras import layers
from keras.initializers import Constant
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

embedding_layer = layers.Embedding(len(word_index)+1,
                            EMBEDDING_DIM,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=maxlen,
                            trainable=False)

X = np.array(X)
Y = np_utils.to_categorical(list(df.c2id))

# split to training set, validation set, test
#https://datascience.stackexchange.com/questions/15135/train-test-validation-set-splitting-in-sklearn
seed = 1234
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=seed)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=seed) # 0.25 x 0.8 = 0.2

# %%
from keras.models import Sequential, Model
from keras.backend import clear_session
clear_session()

from tensorflow.keras import models
## code attention layer
def attention_layer(inputs, neurons):
    x = layers.Permute((2,1))(inputs)
    x = layers.Dense(neurons, activation="softmax")(x)
    x = layers.Permute((2,1), name="attention")(x)
    x = layers.multiply([inputs, x])
    return x

## input
inp = layers.Input(shape=(maxlen,), dtype='int32')
embedding_layer = layers.Embedding(len(word_index)+1,
                            EMBEDDING_DIM,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=maxlen,
                            trainable=False)

## embedding
x = embedding_layer(inp)
## apply attention
x = attention_layer(x, neurons=50)
## 2 layers of bidirectional lstm
x = layers.Bidirectional(layers.LSTM(units=50, dropout=0.5, return_sequences=True))(x)
x = layers.Bidirectional(layers.LSTM(units=50, dropout=0.2))(x)
## final dense layers
x = layers.Dense(64, activation='relu')(x)
y_out = layers.Dense(41, activation='softmax')(x)
## compile
model = models.Model(inp, y_out)
model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 50)]         0           []
#
#  embedding (Embedding)          (None, 50, 100)      11434900    ['input_1[0][0]']
#
#  permute (Permute)              (None, 100, 50)      0           ['embedding[0][0]']
#
#  dense (Dense)                  (None, 100, 50)      2550        ['permute[0][0]']
#
#  attention (Permute)            (None, 50, 100)      0           ['dense[0][0]']
#
#  multiply (Multiply)            (None, 50, 100)      0           ['embedding[0][0]',
#                                                                   'attention[0][0]']
#
#  bidirectional (Bidirectional)  (None, 50, 100)      60400       ['multiply[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 100)         60400       ['bidirectional[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 64)           6464        ['bidirectional_1[0][0]']
#
#  dense_2 (Dense)                (None, 41)           2665        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 11,567,379
# Trainable params: 132,479
# Non-trainable params: 11,434,900
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=64, validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 1699/1699 [==============================] - 40s 17ms/step - loss: 2.6974 - accuracy: 0.3036 - val_loss: 2.4047 - val_accuracy: 0.3630
# Epoch 2/30
# 1699/1699 [==============================] - 41s 24ms/step - loss: 2.2806 - accuracy: 0.3853 - val_loss: 2.1117 - val_accuracy: 0.4234
# Epoch 3/30
# 1699/1699 [==============================] - 28s 17ms/step - loss: 2.1288 - accuracy: 0.4175 - val_loss: 1.9752 - val_accuracy: 0.4560
# Epoch 4/30
# 1699/1699 [==============================] - 29s 17ms/step - loss: 2.0251 - accuracy: 0.4434 - val_loss: 1.8837 - val_accuracy: 0.4775
# Epoch 5/30
# 1699/1699 [==============================] - 28s 17ms/step - loss: 1.9456 - accuracy: 0.4606 - val_loss: 1.8377 - val_accuracy: 0.4918
# Epoch 6/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.8811 - accuracy: 0.4768 - val_loss: 1.7655 - val_accuracy: 0.5079
# Epoch 7/30
# 1699/1699 [==============================] - 29s 17ms/step - loss: 1.8324 - accuracy: 0.4905 - val_loss: 1.7343 - val_accuracy: 0.5182
# Epoch 8/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.7890 - accuracy: 0.4998 - val_loss: 1.6994 - val_accuracy: 0.5220
# Epoch 9/30
# 1699/1699 [==============================] - 29s 17ms/step - loss: 1.7508 - accuracy: 0.5105 - val_loss: 1.6949 - val_accuracy: 0.5281
# Epoch 10/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.7174 - accuracy: 0.5182 - val_loss: 1.6177 - val_accuracy: 0.5445
# Epoch 11/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.6873 - accuracy: 0.5240 - val_loss: 1.5896 - val_accuracy: 0.5526
# Epoch 12/30
# 1699/1699 [==============================] - 30s 18ms/step - loss: 1.6629 - accuracy: 0.5319 - val_loss: 1.6037 - val_accuracy: 0.5453
# Epoch 13/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.6412 - accuracy: 0.5366 - val_loss: 1.5826 - val_accuracy: 0.5513
# Epoch 14/30
# 1699/1699 [==============================] - 28s 17ms/step - loss: 1.6188 - accuracy: 0.5419 - val_loss: 1.5404 - val_accuracy: 0.5622
# Epoch 15/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.6016 - accuracy: 0.5456 - val_loss: 1.5607 - val_accuracy: 0.5611
# Epoch 16/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.5833 - accuracy: 0.5500 - val_loss: 1.5339 - val_accuracy: 0.5655
# Epoch 17/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.5720 - accuracy: 0.5523 - val_loss: 1.5129 - val_accuracy: 0.5698
# Epoch 18/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.5533 - accuracy: 0.5566 - val_loss: 1.4950 - val_accuracy: 0.5738
# Epoch 19/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.5399 - accuracy: 0.5617 - val_loss: 1.5039 - val_accuracy: 0.5729
# Epoch 20/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.5268 - accuracy: 0.5634 - val_loss: 1.4792 - val_accuracy: 0.5777
# Epoch 21/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.5142 - accuracy: 0.5667 - val_loss: 1.4674 - val_accuracy: 0.5817
# Epoch 22/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.5037 - accuracy: 0.5693 - val_loss: 1.4607 - val_accuracy: 0.5827
# Epoch 23/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.4947 - accuracy: 0.5717 - val_loss: 1.4808 - val_accuracy: 0.5771
# Epoch 24/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.4783 - accuracy: 0.5762 - val_loss: 1.4355 - val_accuracy: 0.5870
# Epoch 25/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.4720 - accuracy: 0.5774 - val_loss: 1.4510 - val_accuracy: 0.5844
# Epoch 26/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.4641 - accuracy: 0.5784 - val_loss: 1.4332 - val_accuracy: 0.5891
# Epoch 27/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.4535 - accuracy: 0.5823 - val_loss: 1.4366 - val_accuracy: 0.5889
# Epoch 28/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.4423 - accuracy: 0.5840 - val_loss: 1.4259 - val_accuracy: 0.5932
# Epoch 29/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.4355 - accuracy: 0.5850 - val_loss: 1.4144 - val_accuracy: 0.5958
# Epoch 30/30
# 1699/1699 [==============================] - 28s 16ms/step - loss: 1.4285 - accuracy: 0.5882 - val_loss: 1.4152 - val_accuracy: 0.5961

# %%
#https://www.tensorflow.org/guide/keras/train_and_evaluate
print("Evaluate on test data")
results = model.evaluate(X_test, y_test, batch_size=64)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 567/567 [==============================] - 6s 11ms/step - loss: 1.4156 - accuracy: 0.5977
# test loss, test acc: [1.4156018495559692, 0.5977474451065063]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (6,6)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.title('Training and validation accuracy')
plt.plot(epochs, acc, 'red', label='Training acc')
plt.plot(epochs, val_acc, 'blue', label='Validation acc')
plt.legend()
plt.savefig("train_val_baseline_acc.png")
plt.figure()
plt.title('Training and validation loss')
plt.plot(epochs, loss, 'red', label='Training loss')
plt.plot(epochs, val_loss, 'blue', label='Validation loss')
plt.legend()
plt.savefig("train_val_baseline_loss.png")
plt.show()
