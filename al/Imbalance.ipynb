# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
#REFERENCE: https://www.kaggle.com/hamzamanssor/news-category-classification
import json
list_ = []
with open('News_Category_Dataset_v2.json') as files:
    for file in files:
        list_.append(json.loads(file))

# %%
import pandas as pd
data = pd.DataFrame(list_)

# %%
import pandas as pd
def load_data(file_path):
    df = pd.read_json(file_path, lines = True)
    df = df[df["short_description"] != ""]
    return df[["category"]]

data = load_data('News_Category_Dataset_v2.json')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14,8))
count = data.category.value_counts()
sns.barplot(x=count.index, y=count)
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=90);
